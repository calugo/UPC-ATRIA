# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as manimation


fig = plt.figure()
#Initial Setup
Sn='Cai'
Fn="../snaps/"+str(13035)+".000000"+Sn+".dat"
print Fn
Nk=np.loadtxt(Fn)

axes=plt.imshow(Nk)#, extent = [0,50, 100, 0] )
cax = plt.axes([0.80, 0.1, 0.04, 0.8])
zmin=0.0000
zmax=0.0014
plt.clim(zmin,zmax)
#plt.colorbar(cax=cax)
	#plt.colorbar()
fig.suptitle('$[Ca^{2+}]_i(x_n,y_n,t )$',fontsize=20)
#axes.yaxis.set_tick_params(labelsize=20)
fig.set_size_inches(18.5,10.5)
fig.savefig('Cai2png.png',dpi=500)
fig.savefig('Cai2.svg',dpi=500)
# Out:
# ../snaps/13035.000000Cai.dat

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import LinearLocator, FormatStrFormatter

#fig = plt.figure(figsize=(20,8))
#ax = fig.gca(projection='3d')
X = np.arange(0,1, 0.25)
Y = np.arange(0,02, 0.25)
Nx=len(X)
Ny=len(Y)

Z = np.zeros((Nx,Ny))
print X, Y
for i in range(Nx):
    for j in range(Ny):
        Z[i][j]=1.0*X[i]+1.0*Y[j]
#print X, Y, Z
Xr, Yr = np.meshgrid(X, Y)
Zr = Xr+Yr
print Xr
print Yr
print Zr

print len(Z)
print Z.transpose()

#raw_input()
# Out:
# [ 0.    0.25  0.5   0.75] [ 0.    0.25  0.5   0.75  1.    1.25  1.5   1.75]
# [[ 0.    0.25  0.5   0.75]
#  [ 0.    0.25  0.5   0.75]
#  [ 0.    0.25  0.5   0.75]
#  [ 0.    0.25  0.5   0.75]
#  [ 0.    0.25  0.5   0.75]
#  [ 0.    0.25  0.5   0.75]
#  [ 0.    0.25  0.5   0.75]
#  [ 0.    0.25  0.5   0.75]]
# [[ 0.    0.    0.    0.  ]
#  [ 0.25  0.25  0.25  0.25]
#  [ 0.5   0.5   0.5   0.5 ]
#  [ 0.75  0.75  0.75  0.75]
#  [ 1.    1.    1.    1.  ]
#  [ 1.25  1.25  1.25  1.25]
#  [ 1.5   1.5   1.5   1.5 ]
#  [ 1.75  1.75  1.75  1.75]]
# [[ 0.    0.25  0.5   0.75]
#  [ 0.25  0.5   0.75  1.  ]
#  [ 0.5   0.75  1.    1.25]
#  [ 0.75  1.    1.25  1.5 ]
#  [ 1.    1.25  1.5   1.75]
#  [ 1.25  1.5   1.75  2.  ]
#  [ 1.5   1.75  2.    2.25]
#  [ 1.75  2.    2.25  2.5 ]]
# 4
# [[ 0.    0.25  0.5   0.75]
#  [ 0.25  0.5   0.75  1.  ]
#  [ 0.5   0.75  1.    1.25]
#  [ 0.75  1.    1.25  1.5 ]
#  [ 1.    1.25  1.5   1.75]
#  [ 1.25  1.5   1.75  2.  ]
#  [ 1.5   1.75  2.    2.25]
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import LinearLocator, FormatStrFormatter


fig = plt.figure(figsize=(20,8))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(Xr,Yr,Z.transpose(), rstride=1, cstride=1, cmap=cm.coolwarm,
        linewidth=0, antialiased=False)
#ax.set_zlim(-1.01, 1.01)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import LinearLocator, FormatStrFormatter

Sn='Cai'
Fn="../snaps/"+str(13035)+".000000"+Sn+".dat"
print Fn
Nk=np.loadtxt(Fn)

fig = plt.figure(figsize=(20,8))
ax = fig.gca(projection='3d')
fig.suptitle('$[Ca^{2+}]_i(x_n,y_n,t_k= 1.3 sec )$',fontsize=20)
X = np.arange(0,0.25*300, 0.25)
Y = np.arange(0,0.25*150, 0.25)

anx=len(Nk[0])
bnx=len(Nk[:,0])
Zk=np.zeros((bnx,anx))

print len(X), bnx
print len(Y), anx
raw_input()

for i in range(bnx):
    for j in range(anx):
        Zk[i][j]=1.0*Nk[i][j]
   #print Zk[i]
   #raw_input()
#Zk= np.meshgrid(Nk)
#print X
print len(X), len(Y), bnx, anx
print len(Zk)

Zkx=Zk.transpose()
print("sofar")
raw_input()
Yr, Xr = np.meshgrid(Y,X)
print Xr, len(Xr)
print Zk, len(Zk)

print("sofar2")
raw_input()

surf = ax.plot_surface(Xr,Yr,Zk, rstride=1, cstride=1, cmap=cm.bone,
        linewidth=0, antialiased=False)
#ax.set_zlim(-1.01, 1.01)
ax.view_init(azim =120,elev = 22)
ax.zaxis.set_major_locator(LinearLocator(0.00001))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

#fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()



fig.set_size_inches(18.5,10.5)
fig.savefig('Cai2png.png',dpi=500)
fig.savefig('Cai2.svg',dpi=500)
# Out:
# ../snaps/13035.000000Cai.dat
# 300 300
# 150 150
# 300 150 300 150
# 300
# sofar
# [[  0.     0.     0.   ...,   0.     0.     0.  ]
#  [  0.25   0.25   0.25 ...,   0.25   0.25   0.25]
#  [  0.5    0.5    0.5  ...,   0.5    0.5    0.5 ]
#  ...,
#  [ 74.25  74.25  74.25 ...,  74.25  74.25  74.25]
#  [ 74.5   74.5   74.5  ...,  74.5   74.5   74.5 ]
#  [ 74.75  74.75  74.75 ...,  74.75  74.75  74.75]] 300
# [[ 0.00012898  0.00012898  0.00012898 ...,  0.00012898  0.00012898
#    0.00012898]
#  [ 0.00012905  0.00012905  0.00012905 ...,  0.00012905  0.00012905
#    0.00012905]
#  [ 0.00012919  0.00012919  0.00012919 ...,  0.00012919  0.00012919
#    0.00012919]
#  ...,
#  [ 0.00010769  0.00010769  0.00010769 ...,  0.00010769  0.00010769
#    0.00010769]
#  [ 0.00010696  0.00010696  0.00010696 ...,  0.00010696  0.00010696
#    0.00010696]
#  [ 0.00010592  0.00010592  0.00010592 ...,  0.00010592  0.00010592
#    0.00010592]] 300
# sofar2

# %%
 matplotlib.get_configdir()
# Out:
# u'/home/carlos/.config/matplotlib'
